# %%
import pandas as pd

# %%
#reading csv

df=pd.read_csv("C:\\Users\\nikhil\\Desktop\\food_deliverydata.csv")

# %%
# first 5 rows of data
df.head()
# Out:
#    customer_id     First Time     Recent Time  # of Orders  \
# 0      1269647  6/29/15 10:57   12/10/15 2:18          212
# 1       167631   7/4/15 15:39  12/15/15 14:42          211
# 2       301524   6/26/15 9:56   12/9/15 20:45          189
# 3      1268254    7/1/15 1:51   12/14/15 1:43          184
# 4       357161  7/11/15 18:34  12/19/15 23:26          182
#
#    # of Orders in last 7 days  # of Orders in last 4 weeks  Amount  \
# 0                         6.0                         43.0  138808
# 1                         8.0                         19.0   56404
# 2                         9.0                         33.0   36020
# 3                         6.0                         37.0   32489
# 4                         4.0                         23.0   85150
#
#    Amount in last 7 days  Amount in last 4 weeks  Avg_DistanceFromResturant  \
# 0                   4291                   26853                        1.6
# ...

# %%
# no of rows and columns

df.shape
# Out:
# (10000, 11)

# %%
# columns in data

df.columns
# Out:
# Index(['customer_id', 'First Time', 'Recent Time', '# of Orders',
#        '# of Orders in last 7 days', '# of Orders in last 4 weeks', 'Amount',
#        'Amount in last 7 days', 'Amount in last 4 weeks',
#        'Avg_DistanceFromResturant', 'Avg_DeliveryTime'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# nrows: to show n no of rows
df1=pd.read_csv("C:\\Users\\nikhil\\Desktop\\food_deliverydata.csv",nrows=1)
df1
# Out:
#    customer_id     First Time    Recent Time  # of Orders  \
# 0      1269647  6/29/15 10:57  12/10/15 2:18          212
#
#    # of Orders in last 7 days  # of Orders in last 4 weeks  Amount  \
# 0                           6                           43  138808
#
#    Amount in last 7 days  Amount in last 4 weeks  Avg_DistanceFromResturant  \
# 0                   4291                   26853                        1.6
#
#    Avg_DeliveryTime
# 0                51

# %%
# show top 3 rows only
df1=df=pd.read_csv("C:\\Users\\nikhil\\Desktop\\food_deliverydata.csv",nrows=3)
df1
# Out:
#    customer_id     First Time     Recent Time  # of Orders  \
# 0      1269647  6/29/15 10:57   12/10/15 2:18          212
# 1       167631   7/4/15 15:39  12/15/15 14:42          211
# 2       301524   6/26/15 9:56   12/9/15 20:45          189
#
#    # of Orders in last 7 days  # of Orders in last 4 weeks  Amount  \
# 0                           6                           43  138808
# 1                           8                           19   56404
# 2                           9                           33   36020
#
#    Amount in last 7 days  Amount in last 4 weeks  Avg_DistanceFromResturant  \
# 0                   4291                   26853                        1.6
# 1                   1925                    4177                        2.2
# 2                   1772                    6404                        2.5
#
#    Avg_DeliveryTime
# 0                51
# 1                42
# 2                57

# %%
# usecols: show only first column and 10 rows
df1=df=pd.read_csv("C:\\Users\\nikhil\\Desktop\\food_deliverydata.csv",usecols=[0],nrows=10)
df1
# Out:
#    customer_id
# 0      1269647
# 1       167631
# 2       301524
# 3      1268254
# 4       357161
# 5      1294857
# 6       387095
# 7       785080
# 8      1288527
# 9      1111111

# %%
# only 1,2,3 column
df1=df=pd.read_csv("C:\\Users\\nikhil\\Desktop\\food_deliverydata.csv",usecols=[0,1,2],nrows=5)
df1
# Out:
#    customer_id     First Time     Recent Time
# 0      1269647  6/29/15 10:57   12/10/15 2:18
# 1       167631   7/4/15 15:39  12/15/15 14:42
# 2       301524   6/26/15 9:56   12/9/15 20:45
# 3      1268254    7/1/15 1:51   12/14/15 1:43
# 4       357161  7/11/15 18:34  12/19/15 23:26

# %%
#skiprows: skip the first row
df1=df=pd.read_csv("C:\\Users\\nikhil\\Desktop\\food_deliverydata.csv",usecols=[0,1,2],
                   nrows=5,skiprows=1)
df1
# Out:
#    1269647  6/29/15 10:57   12/10/15 2:18
# 0   167631   7/4/15 15:39  12/15/15 14:42
# 1   301524   6/26/15 9:56   12/9/15 20:45
# 2  1268254    7/1/15 1:51   12/14/15 1:43
# 3   357161  7/11/15 18:34  12/19/15 23:26
# 4  1294857   6/15/15 9:00  11/25/15 14:01

# %%
df1=df=pd.read_csv("C:\\Users\\nikhil\\Desktop\\food_deliverydata.csv",usecols=[0,1,2],nrows=5)
df1
# Out:
#    customer_id     First Time     Recent Time
# 0      1269647  6/29/15 10:57   12/10/15 2:18
# 1       167631   7/4/15 15:39  12/15/15 14:42
# 2       301524   6/26/15 9:56   12/9/15 20:45
# 3      1268254    7/1/15 1:51   12/14/15 1:43
# 4       357161  7/11/15 18:34  12/19/15 23:26

# %%
# index_col: make the index of dataframe as 'customer_id'

df1=df=pd.read_csv("C:\\Users\\nikhil\\Desktop\\food_deliverydata.csv",usecols=[0,1,2],
                   nrows=5,index_col='customer_id')
df1
# Out:
#                 First Time     Recent Time
# customer_id
# 1269647      6/29/15 10:57   12/10/15 2:18
# 167631        7/4/15 15:39  12/15/15 14:42
# 301524        6/26/15 9:56   12/9/15 20:45
# 1268254        7/1/15 1:51   12/14/15 1:43
# 357161       7/11/15 18:34  12/19/15 23:26

# %%
# make index as first column:

df1=df=pd.read_csv("C:\\Users\\nikhil\\Desktop\\food_deliverydata.csv",usecols=[0,1,2],
                   nrows=5,index_col=1)
df1
# Out:
#                customer_id     Recent Time
# First Time
# 6/29/15 10:57      1269647   12/10/15 2:18
# 7/4/15 15:39        167631  12/15/15 14:42
# 6/26/15 9:56        301524   12/9/15 20:45
# 7/1/15 1:51        1268254   12/14/15 1:43
# 7/11/15 18:34       357161  12/19/15 23:26

# %%
df1=df=pd.read_csv("C:\\Users\\nikhil\\Desktop\\food_deliverydata.csv",nrows=3)
df1
# Out:
#    customer_id     First Time     Recent Time  # of Orders  \
# 0      1269647  6/29/15 10:57   12/10/15 2:18          212
# 1       167631   7/4/15 15:39  12/15/15 14:42          211
# 2       301524   6/26/15 9:56   12/9/15 20:45          189
#
#    # of Orders in last 7 days  # of Orders in last 4 weeks  Amount  \
# 0                           6                           43  138808
# 1                           8                           19   56404
# 2                           9                           33   36020
#
#    Amount in last 7 days  Amount in last 4 weeks  Avg_DistanceFromResturant  \
# 0                   4291                   26853                        1.6
# 1                   1925                    4177                        2.2
# 2                   1772                    6404                        2.5
#
#    Avg_DeliveryTime
# 0                51
# 1                42
# 2                57

# %%
# dtype:to change datatype,
#customer_id datatype is changed
df1=df=pd.read_csv("C:\\Users\\nikhil\\Desktop\\food_deliverydata.csv",nrows=3,
                  dtype={'customer_id':'float'})
df1
# Out:
#    customer_id     First Time     Recent Time  # of Orders  \
# 0    1269647.0  6/29/15 10:57   12/10/15 2:18          212
# 1     167631.0   7/4/15 15:39  12/15/15 14:42          211
# 2     301524.0   6/26/15 9:56   12/9/15 20:45          189
#
#    # of Orders in last 7 days  # of Orders in last 4 weeks  Amount  \
# 0                           6                           43  138808
# 1                           8                           19   56404
# 2                           9                           33   36020
#
#    Amount in last 7 days  Amount in last 4 weeks  Avg_DistanceFromResturant  \
# 0                   4291                   26853                        1.6
# 1                   1925                    4177                        2.2
# 2                   1772                    6404                        2.5
#
#    Avg_DeliveryTime
# 0                51
# 1                42
# 2                57
