# %% [markdown]
#   ## PANDAS CONCAT

# %% [markdown]
# Pandas provides various facilities for easily combining together series,dataframe and panel objects

# %%
import pandas as pd

# %% [markdown]
# ### Concat on series:

# %%
sr1=pd.Series([0,1,2,3])
sr1
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# dtype: int64

# %%
sr2=pd.Series([5,6,7,8])
sr2
# Out:
# 0    5
# 1    6
# 2    7
# 3    8
# dtype: int64

# %%
pd.concat([sr1,sr2])
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 0    5
# 1    6
# 2    7
# 3    8
# dtype: int64

# %%
sr3=pd.Series([6,7,8,9,10,11])
sr3
# Out:
# 0     6
# 1     7
# 2     8
# 3     9
# 4    10
# 5    11
# dtype: int64

# %%
pd.concat([sr2,sr3])
# Out:
# 0     5
# 1     6
# 2     7
# 3     8
# 0     6
# 1     7
# 2     8
# 3     9
# 4    10
# 5    11
# dtype: int64

# %%
sr4=pd.Series(['a','b','c','d'])
sr4
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
pd.concat([sr3,sr4])
# Out:
# 0     6
# 1     7
# 2     8
# 3     9
# 4    10
# 5    11
# 0     a
# 1     b
# 2     c
# 3     d
# dtype: object

# %% [markdown]
# #### axis=0/1;   0:concat vertically ,1: concat horizontally  ; default is 0

# %%
pd.concat([sr3,sr4],axis=0)
# Out:
# 0     6
# 1     7
# 2     8
# 3     9
# 4    10
# 5    11
# 0     a
# 1     b
# 2     c
# 3     d
# dtype: object

# %%
pd.concat([sr3,sr4],axis=1)
# Out:
#     0    1
# 0   6    a
# 1   7    b
# 2   8    c
# 3   9    d
# 4  10  NaN
# 5  11  NaN

# %% [markdown]
# #### ignore_index=True/False ; True means index is in systematic order;  default is False

# %%
pd.concat([sr3,sr4],axis=0,ignore_index=True)
# Out:
# 0     6
# 1     7
# 2     8
# 3     9
# 4    10
# 5    11
# 6     a
# 7     b
# 8     c
# 9     d
# dtype: object

# %% [markdown]
# ### Concat on dataframes:

# %%
# first dataframe created
df1=pd.DataFrame({"ID":[1,2,3,4],"Name":['A','B','C','D'],"Class":[9,10,11,12]})
df1
# Out:
#    ID Name  Class
# 0   1    A      9
# 1   2    B     10
# 2   3    C     11
# 3   4    D     12

# %%
# second dataframe created
df2=pd.DataFrame({"ID":[11,12,13,14],"Name":['AA','BB','CC','DD'],"Class":[5,6,7,8]})
df2
# Out:
#    ID Name  Class
# 0  11   AA      5
# 1  12   BB      6
# 2  13   CC      7
# 3  14   DD      8

# %%
# concat 2 dataframe
pd.concat([df1,df2])
# Out:
#    ID Name  Class
# 0   1    A      9
# 1   2    B     10
# 2   3    C     11
# 3   4    D     12
# 0  11   AA      5
# 1  12   BB      6
# 2  13   CC      7
# 3  14   DD      8

# %%
pd.concat([df1,df2],axis=0)
# Out:
#    ID Name  Class
# 0   1    A      9
# 1   2    B     10
# 2   3    C     11
# 3   4    D     12
# 0  11   AA      5
# 1  12   BB      6
# 2  13   CC      7
# 3  14   DD      8

# %%
# axis =1 i.e dataframe are concated side-by-side(horizontally) 
pd.concat([df1,df2],axis=1)
# Out:
#    ID Name  Class  ID Name  Class
# 0   1    A      9  11   AA      5
# 1   2    B     10  12   BB      6
# 2   3    C     11  13   CC      7
# 3   4    D     12  14   DD      8

# %%
pd.concat([df1,df2],axis=0)
# Out:
#    ID Name  Class
# 0   1    A      9
# 1   2    B     10
# 2   3    C     11
# 3   4    D     12
# 0  11   AA      5
# 1  12   BB      6
# 2  13   CC      7
# 3  14   DD      8

# %% [markdown]
# #### Ignore_index:

# %%
pd.concat([df1,df2],axis=0,ignore_index=False)
# Out:
#    ID Name  Class
# 0   1    A      9
# 1   2    B     10
# 2   3    C     11
# 3   4    D     12
# 0  11   AA      5
# 1  12   BB      6
# 2  13   CC      7
# 3  14   DD      8

# %%
# ignore_index= True i.e index systematically (0 to 7)
pd.concat([df1,df2],axis=0,ignore_index=True)
# Out:
#    ID Name  Class
# 0   1    A      9
# 1   2    B     10
# 2   3    C     11
# 3   4    D     12
# 4  11   AA      5
# 5  12   BB      6
# 6  13   CC      7
# 7  14   DD      8

# %% [markdown]
# ### keys:name you like to give to your dataframe

# %%
# here axis=0:
pd.concat([df1,df2],keys=['first dataframe','second dataframe'])
# Out:
#                     ID Name  Class
# first dataframe  0   1    A      9
#                  1   2    B     10
#                  2   3    C     11
#                  3   4    D     12
# second dataframe 0  11   AA      5
#                  1  12   BB      6
#                  2  13   CC      7
#                  3  14   DD      8

# %%
# here axis=1:
pd.concat([df1,df2],keys=['first dataframe','second dataframe'],axis=1)
# Out:
#   first dataframe            second dataframe
#                ID Name Class               ID Name Class
# 0               1    A     9               11   AA     5
# 1               2    B    10               12   BB     6
# 2               3    C    11               13   CC     7
# 3               4    D    12               14   DD     8

# %%
# keys parameter dont work :
pd.concat([df1,df2],keys=['first dataframe','second dataframe'],ignore_index=True)
# Out:
#    ID Name  Class
# 0   1    A      9
# 1   2    B     10
# 2   3    C     11
# 3   4    D     12
# 4  11   AA      5
# 5  12   BB      6
# 6  13   CC      7
# 7  14   DD      8

# %%
df1
# Out:
#    ID Name  Class
# 0   1    A      9
# 1   2    B     10
# 2   3    C     11
# 3   4    D     12

# %%
df3=pd.DataFrame({"ID":[5,6],"Name":['E','F'],"Class":[13,14]})
df3
# Out:
#    ID Name  Class
# 0   5    E     13
# 1   6    F     14

# %%
pd.concat([df1,df3])
# Out:
#    ID Name  Class
# 0   1    A      9
# 1   2    B     10
# 2   3    C     11
# 3   4    D     12
# 0   5    E     13
# 1   6    F     14

# %%
pd.concat([df1,df3],axis=1)
# Out:
#    ID Name  Class   ID Name  Class
# 0   1    A      9  5.0    E   13.0
# 1   2    B     10  6.0    F   14.0
# 2   3    C     11  NaN  NaN    NaN
# 3   4    D     12  NaN  NaN    NaN

# %%
pd.concat([df1,df3],ignore_index=True)
# Out:
#    ID Name  Class
# 0   1    A      9
# 1   2    B     10
# 2   3    C     11
# 3   4    D     12
# 4   5    E     13
# 5   6    F     14

# %%
df1
# Out:
#    ID Name  Class
# 0   1    A      9
# 1   2    B     10
# 2   3    C     11
# 3   4    D     12

# %%
df3
# Out:
#    ID Name  Class
# 0   5    E     13
# 1   6    F     14

# %%
pd.concat([df1,df3])
# Out:
#    ID Name  Class
# 0   1    A      9
# 1   2    B     10
# 2   3    C     11
# 3   4    D     12
# 0   5    E     13
# 1   6    F     14

# %%
pd.concat([df1,df3],join="outer")
# Out:
#    ID Name  Class
# 0   1    A      9
# 1   2    B     10
# 2   3    C     11
# 3   4    D     12
# 0   5    E     13
# 1   6    F     14

# %%
pd.concat([df1,df3],join="inner")
# Out:
#    ID Name  Class
# 0   1    A      9
# 1   2    B     10
# 2   3    C     11
# 3   4    D     12
# 0   5    E     13
# 1   6    F     14

# %%
pd.concat([df1,df3],axis=1)
# Out:
#    ID Name  Class   ID Name  Class
# 0   1    A      9  5.0    E   13.0
# 1   2    B     10  6.0    F   14.0
# 2   3    C     11  NaN  NaN    NaN
# 3   4    D     12  NaN  NaN    NaN

# %%
pd.concat([df1,df3],axis=1,join="inner")
# Out:
#    ID Name  Class  ID Name  Class
# 0   1    A      9   5    E     13
# 1   2    B     10   6    F     14

# %% [markdown]
# ### join_axes:

# %%
# join_axes:to return specific dataframe index
## join_axes=df3.index means give all index of df1;same as join=outer
pd.concat([df1,df3],axis=1,join_axes=[df1.index])
# Out:
#    ID Name  Class   ID Name  Class
# 0   1    A      9  5.0    E   13.0
# 1   2    B     10  6.0    F   14.0
# 2   3    C     11  NaN  NaN    NaN
# 3   4    D     12  NaN  NaN    NaN

# %%
# join_axes=df3.index means give all index of df3;same as join=inner
pd.concat([df1,df3],axis=1,join_axes=[df3.index])
# Out:
#    ID Name  Class  ID Name  Class
# 0   1    A      9   5    E     13
# 1   2    B     10   6    F     14

# %%
# dataframe created with  different labels
df4=pd.DataFrame({"Rollno":[22,33],"Grade":['Good','Excellent']})
df4
# Out:
#    Rollno      Grade
# 0      22       Good
# 1      33  Excellent

# %%
# 2 different datframes concated
pd.concat([df1,df4],axis=1)
# Out:
#    ID Name  Class  Rollno      Grade
# 0   1    A      9    22.0       Good
# 1   2    B     10    33.0  Excellent
# 2   3    C     11     NaN        NaN
# 3   4    D     12     NaN        NaN

# %%
pd.concat([df1,df4],axis=0)
#warning come
# Out:
# C:\Users\nikhil\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#    Class      Grade   ID Name  Rollno
# 0    9.0        NaN  1.0    A     NaN
# 1   10.0        NaN  2.0    B     NaN
# 2   11.0        NaN  3.0    C     NaN
# 3   12.0        NaN  4.0    D     NaN
# 0    NaN       Good  NaN  NaN    22.0
# 1    NaN  Excellent  NaN  NaN    33.0

# %%
# added sort=False ;no warning come
pd.concat([df1,df4],sort=False)
# Out:
#     ID Name  Class  Rollno      Grade
# 0  1.0    A    9.0     NaN        NaN
# 1  2.0    B   10.0     NaN        NaN
# 2  3.0    C   11.0     NaN        NaN
# 3  4.0    D   12.0     NaN        NaN
# 0  NaN  NaN    NaN    22.0       Good
# 1  NaN  NaN    NaN    33.0  Excellent
